# %%
from  sklearn.tree import DecisionTreeClassifier

# %%
features = [
    [ 75.83 , 365000],
    [57.44,285000]
    ,[68.97,400000]
    ,[61.79,500000]
    ,[59.09,400000]
    ,[57.34,400000]
    ,[56.81,350000]
    ,[60.04,350000]
    ,[63.59,400000]
    ]

label =  [
 0,  # high LTV → reject
 1,  # low LTV → approve
 1,
 1,
 1,
 1,
 1,
 1,
 1
]

# %%
clt = DecisionTreeClassifier()

clt = clt.fit(features,label)

clt.predict([[99,3000]])
# Out:
# array([0])
